# %% [markdown]
# # Data Challenge 4
#
# **L'objectif est d'appliquer des modèles d'analyse prédictive sur des logs de parties en 1vs1 de StarCraft2, et de juger la capacité à entraîner un modèle à prédire le vainqueur d'un match particulier.**
#
#
# Je me suis focalisé sur 2 approches:
#
# * Etant guidés par les résultats (victoire ou défaite du joueur p1 pour chaque partie, on est dans un cas clair **d'apprentissage supervisé**, et j'ai testé différents algorithmes disponibles dans la librairie sklearn de Python.
#
#
# * Le nombre de colonnes (features) peut être réduit, en identifiant les caractéristiques les plus importantes ou celles qui décrivent la même information (collinéaire). La diminution de la dimensionnalité du jeu de données vise à :
#
#     * **Tester les meilleurs jeux d'hyperparamètres pour chaque modèle**, ce qui est coûteux sur le jeu complet
#
#     * **Tenter d'appliquer des modèles de collection**, et restreindre le nombre de variable à un jeu sur lequel il
#      est possible de réfléchir et dégager des axes forts (par exemple : quelle caractéristique le joueur peut améliorer pour gagner plus souvent ? Quelles corrélations entre les caractéristiques ?

# %% [markdown]
# ## Sommaire
#
# 1. Import des données
# 2. Type des colonnes, proportions de données manquantes, par quoi les remplacer ?
# 3. préparation d'un jeu "complet" et d'un jeu "light"
#     1. Diagramme de corrélation
#     2. PCA et Explained Variance
# 4. Modèles d'apprentissage supervisé
#     1. Cross validation
#     2. Normalisation
#     3. Optimisation des algorithmes (jeu "light")
#     4. Test sur les deux jeux

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.decomposition import PCA # Principal Component Analysis module
from sklearn.cluster import KMeans # KMeans clustering 
import matplotlib.pyplot as plt # Python defacto plotting library
import seaborn as sns # More snazzy plotting library
# %matplotlib inline

# %%
df = pd.read_csv("sc2_dataset_lt_5mins.csv")

# %% [markdown]
# Analysons cet ensemble de données. Texte ou numérique ? Proportion de données manquantes ?
# Que faire des données manquantes ? Supprimer les colonnes, les remplacer par des zeros, ou la médiane ?

# %%
# 328 colonnes
df.head()
# Out:
#    _p1_win_game  game_length      p1_APM  p1_APM_wo_select  p1_Archon  \
# 0             0   505.525072  253.755960        117.501591        NaN
# 1             1   808.316816  409.814560        184.973045        NaN
# 2             1   615.327680  119.058515         50.509673        NaN
# 3             1   447.150144  283.797292        108.285775        NaN
# 4             1   693.732336  110.532544         56.996046        NaN
#
#    p1_Armory  p1_Assimilator  p1_Auto_Turret  p1_Baneling_Nest  p1_Banshee  \
# 0        NaN             NaN             NaN               NaN         NaN
# 1        NaN             NaN             NaN               1.0         NaN
# 2        NaN             NaN             NaN               1.0         NaN
# 3        NaN             2.0             NaN               NaN         NaN
# 4        NaN             NaN             NaN               NaN         NaN
#
#        ...        p2_min_distance_from_opponent  p2_nb_scooting  \
# 0      ...                             1.326082             126
# 1      ...                             2.195000              34
# 2      ...                             0.701632             124
# 3      ...                           109.445248               0
# 4      ...                             1.357620              62
#
#    p2_selected_hotkeys  p2_spent_gas  p2_spent_minerals  \
# 0                  650           125               5625
# 1                  847          5775              26000
# 2                    2          1200               7275
# 3                   83             0              10100
# 4                   24          3350              12550
#
#    p2_timing_1st_scooting  p2_to_Orbital_Command_Command_Center  \
# 0               45.788680                                   NaN
# 1              117.381424                                   3.0
# 2              475.345144                                   NaN
# 3                     NaN                                   2.0
# 4              631.703336                                   NaN
#
#    p2_to_Planetary_Fortress_Command_Center  p2_to_Warp_Gate_Gateway  \
# 0                                      NaN                      NaN
# 1                                      NaN                      NaN
# 2                                      NaN                      1.0
# 3                                      NaN                      NaN
# 4                                      NaN                      NaN
#
#    p2_unit_types
# 0              5
# 1              7
# 2              3
# 3              2
# 4              4
#
# [5 rows x 328 columns]

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34534 entries, 0 to 34533
# Data columns (total 328 columns):
# _p1_win_game                                    34534 non-null int64
# game_length                                     34534 non-null float64
# p1_APM                                          34534 non-null float64
# p1_APM_wo_select                                34534 non-null float64
# p1_Archon                                       4 non-null float64
# p1_Armory                                       6465 non-null float64
# p1_Assimilator                                  11096 non-null float64
# p1_Auto_Turret                                  473 non-null float64
# p1_Baneling_Nest                                5997 non-null float64
# p1_Banshee                                      2340 non-null float64
# p1_Barracks                                     10861 non-null float64
# p1_Battlecruiser                                316 non-null float64
# p1_Building_Attack                              110 non-null float64
# p1_Bunker                                       7116 non-null float64
# p1_Carrier                                      176 non-null float64
# p1_Colossus                                     4164 non-null float64
# p1_Command_Center                               9844 non-null float64
# p1_Corruptor                                    2161 non-null float64
# p1_Creep_Tumor                                  8247 non-null float64
# p1_Cybernetics_Core                             11066 non-null float64
# p1_Dark                                         984 non-null float64
# p1_Dark_Shrine                                  1626 non-null float64
# p1_Drone                                        12448 non-null float64
# p1_Engineering_Bay                              8763 non-null float64
# p1_Evolution_Chamber                            9731 non-null float64
# p1_Extractor                                    12409 non-null float64
# p1_Factory                                      10117 non-null float64
# p1_Fleet_Beacon                                 669 non-null float64
# p1_Forge                                        7657 non-null float64
# p1_Fusion_Core                                  426 non-null float64
# p1_Gateway                                      11199 non-null float64
# p1_Ghost                                        968 non-null float64
# p1_Ghost_Academy                                1348 non-null float64
# p1_Hatchery                                     12041 non-null float64
# p1_Hellion                                      3972 non-null float64
# p1_High                                         1443 non-null float64
# p1_Hive                                         3867 non-null float64
# p1_Hydralisk                                    1874 non-null float64
# p1_Hydralisk_Den                                2261 non-null float64
# p1_Immortal                                     5511 non-null float64
# p1_Infestation_Pit                              5878 non-null float64
# p1_Infestor                                     3309 non-null float64
# p1_Lair                                         10309 non-null float64
# p1_Lair_Upgrade_Hatchery                        173 non-null float64
# p1_Marauder                                     6838 non-null float64
# p1_Marine                                       10819 non-null float64
# p1_Medivac                                      7242 non-null float64
# p1_Missile_Turret                               5928 non-null float64
# p1_Mothership                                   396 non-null float64
# p1_Mutalisk                                     3653 non-null float64
# p1_Nexus                                        9030 non-null float64
# p1_Nydus_Network                                393 non-null float64
# p1_Nydus_Worm                                   298 non-null float64
# p1_Observer                                     6605 non-null float64
# p1_Orbital_Command_Upgrade_Command_Center       269 non-null float64
# p1_Overlord                                     12440 non-null float64
# p1_Phoenix                                      1180 non-null float64
# p1_Photon_Cannon                                5667 non-null float64
# p1_Planetary_Fortress_Upgrade_Command_Center    224 non-null float64
# p1_Point_Defense                                474 non-null float64
# p1_Probe                                        11219 non-null float64
# p1_Protoss_Air_Armor_1                          210 non-null float64
# p1_Protoss_Air_Armor_2                          54 non-null float64
# p1_Protoss_Air_Armor_3                          21 non-null float64
# p1_Protoss_Air_Weapons_1                        503 non-null float64
# p1_Protoss_Air_Weapons_2                        144 non-null float64
# p1_Protoss_Air_Weapons_3                        57 non-null float64
# p1_Protoss_Ground_Armor_1                       4639 non-null float64
# p1_Protoss_Ground_Armor_2                       2364 non-null float64
# p1_Protoss_Ground_Armor_3                       1229 non-null float64
# p1_Protoss_Ground_Weapons_1                     6181 non-null float64
# p1_Protoss_Ground_Weapons_2                     3908 non-null float64
# p1_Protoss_Ground_Weapons_3                     2261 non-null float64
# p1_Protoss_Shield_1                             1385 non-null float64
# p1_Protoss_Shield_2                             460 non-null float64
# p1_Protoss_Shield_3                             172 non-null float64
# p1_Pylon                                        11218 non-null float64
# p1_Queen                                        12408 non-null float64
# p1_Raven                                        1099 non-null float64
# p1_Reactor_Barracks                             8810 non-null float64
# p1_Reactor_Factory                              4003 non-null float64
# p1_Reactor_Starport                             3652 non-null float64
# p1_Reaper                                       900 non-null float64
# p1_Refinery                                     10724 non-null float64
# p1_Roach                                        7759 non-null float64
# p1_Roach_Warren                                 8484 non-null float64
# p1_Robotics_Bay                                 4709 non-null float64
# p1_Robotics_Facility                            8245 non-null float64
# p1_SCV                                          10869 non-null float64
# p1_Sensor_Tower                                 1094 non-null float64
# p1_Sentry                                       7622 non-null float64
# p1_Siege                                        6419 non-null float64
# p1_Spawning_Pool                                12446 non-null float64
# p1_Spine_Crawler                                9154 non-null float64
# p1_Spire                                        5938 non-null float64
# p1_Spore_Crawler                                4347 non-null float64
# p1_Stalker                                      9907 non-null float64
# p1_Stargate                                     2375 non-null float64
# p1_Starport                                     9103 non-null float64
# p1_Supply_Depot                                 10864 non-null float64
# p1_Tech_Lab                                     10531 non-null float64
# p1_Templar_Archives                             2480 non-null float64
# p1_Terran_Building                              430 non-null float64
# p1_Terran_Building_Armor                        430 non-null float64
# p1_Terran_Hi-sec_Auto_Tracking                  497 non-null float64
# p1_Terran_Infantry_Armor_1                      5801 non-null float64
# p1_Terran_Infantry_Armor_2                      3328 non-null float64
# p1_Terran_Infantry_Armor_3                      1710 non-null float64
# p1_Terran_Infantry_Weapons_1                    6917 non-null float64
# p1_Terran_Infantry_Weapons_2                    4079 non-null float64
# p1_Terran_Infantry_Weapons_3                    2331 non-null float64
# p1_Terran_Neosteel_Frame                        126 non-null float64
# p1_Terran_Ship_Plating_1                        555 non-null float64
# p1_Terran_Ship_Plating_2                        218 non-null float64
# p1_Terran_Ship_Plating_3                        72 non-null float64
# p1_Terran_Ship_Weapons_1                        1241 non-null float64
# p1_Terran_Ship_Weapons_2                        520 non-null float64
# p1_Terran_Ship_Weapons_3                        179 non-null float64
# p1_Terran_Vehicle_Plating_1                     1226 non-null float64
# p1_Terran_Vehicle_Plating_2                     575 non-null float64
# p1_Terran_Vehicle_Plating_3                     260 non-null float64
# p1_Terran_Vehicle_Weapons_1                     3089 non-null float64
# p1_Terran_Vehicle_Weapons_2                     1596 non-null float64
# p1_Terran_Vehicle_Weapons_3                     648 non-null float64
# p1_Thor                                         1951 non-null float64
# p1_Twilight_Council                             6651 non-null float64
# p1_Ultralisk                                    777 non-null float64
# p1_Ultralisk_Cavern                             1039 non-null float64
# p1_Viking                                       4309 non-null float64
# p1_Void                                         1542 non-null float64
# p1_Warp                                         1742 non-null float64
# p1_Zealot                                       10329 non-null float64
# p1_Zerg_Flyer_Attacks_1                         2573 non-null float64
# p1_Zerg_Flyer_Attacks_2                         923 non-null float64
# p1_Zerg_Flyer_Attacks_3                         201 non-null float64
# p1_Zerg_Flyer_Carapace_1                        943 non-null float64
# p1_Zerg_Flyer_Carapace_2                        280 non-null float64
# p1_Zerg_Flyer_Carapace_3                        65 non-null float64
# p1_Zerg_Ground_Carapace_1                       6699 non-null float64
# p1_Zerg_Ground_Carapace_2                       4208 non-null float64
# p1_Zerg_Ground_Carapace_3                       1562 non-null float64
# p1_Zerg_Melee_Attacks_1                         4746 non-null float64
# p1_Zerg_Melee_Attacks_2                         2895 non-null float64
# p1_Zerg_Melee_Attacks_3                         1243 non-null float64
# p1_Zerg_Missile_Attacks_1                       5450 non-null float64
# p1_Zerg_Missile_Attacks_2                       3307 non-null float64
# p1_Zerg_Missile_Attacks_3                       780 non-null float64
# p1_Zergling                                     12213 non-null float64
# p1_an                                           62 non-null float64
# p1_assigned_hotkeys                             34534 non-null int64
# p1_building_types                               34534 non-null int64
# p1_collected_gas                                34534 non-null float64
# p1_collected_minerals                           34534 non-null float64
# p1_max_distance_from_opponent                   34446 non-null float64
# p1_mean_distance_from_opponent                  34446 non-null float64
# p1_min_distance_from_opponent                   34446 non-null float64
# p1_nb_scooting                                  34534 non-null int64
# p1_selected_hotkeys                             34534 non-null int64
# p1_spent_gas                                    34534 non-null int64
# p1_spent_minerals                               34534 non-null int64
# p1_timing_1st_scooting                          33982 non-null float64
# p1_to_Orbital_Command_Command_Center            10665 non-null float64
# p1_to_Planetary_Fortress_Command_Center         2838 non-null float64
# p1_to_Warp_Gate_Gateway                         10430 non-null float64
# p1_unit_types                                   34534 non-null int64
# p2_APM                                          34534 non-null float64
# p2_APM_wo_select                                34534 non-null float64
# p2_Archon                                       5 non-null float64
# p2_Armory                                       6614 non-null float64
# p2_Assimilator                                  11306 non-null float64
# p2_Auto_Turret                                  511 non-null float64
# p2_Baneling_Nest                                5937 non-null float64
# p2_Banshee                                      2456 non-null float64
# p2_Barracks                                     11084 non-null float64
# p2_Battlecruiser                                336 non-null float64
# p2_Building_Attack                              91 non-null float64
# p2_Bunker                                       7271 non-null float64
# p2_Carrier                                      187 non-null float64
# p2_Colossus                                     4184 non-null float64
# p2_Command_Center                               10021 non-null float64
# p2_Corruptor                                    2033 non-null float64
# p2_Creep_Tumor                                  7791 non-null float64
# p2_Cybernetics_Core                             11274 non-null float64
# p2_Dark                                         1120 non-null float64
# p2_Dark_Shrine                                  1722 non-null float64
# p2_Drone                                        12055 non-null float64
# p2_Engineering_Bay                              8861 non-null float64
# p2_Evolution_Chamber                            9302 non-null float64
# p2_Extractor                                    12015 non-null float64
# p2_Factory                                      10331 non-null float64
# p2_Fleet_Beacon                                 680 non-null float64
# p2_Forge                                        7890 non-null float64
# p2_Fusion_Core                                  451 non-null float64
# p2_Gateway                                      11383 non-null float64
# p2_Ghost                                        1009 non-null float64
# p2_Ghost_Academy                                1418 non-null float64
# p2_Hatchery                                     11657 non-null float64
# p2_Hellion                                      4033 non-null float64
# p2_High                                         1531 non-null float64
# p2_Hive                                         3734 non-null float64
# p2_Hydralisk                                    1751 non-null float64
# p2_Hydralisk_Den                                2132 non-null float64
# p2_Immortal                                     5553 non-null float64
# p2_Infestation_Pit                              5672 non-null float64
# p2_Infestor                                     3164 non-null float64
# p2_Lair                                         9888 non-null float64
# p2_Lair_Upgrade_Hatchery                        186 non-null float64
# p2_Marauder                                     6714 non-null float64
# p2_Marine                                       11043 non-null float64
# p2_Medivac                                      7496 non-null float64
# p2_Missile_Turret                               5934 non-null float64
# p2_Mothership                                   434 non-null float64
# p2_Mutalisk                                     3742 non-null float64
# p2_Nexus                                        9209 non-null float64
# p2_Nydus_Network                                391 non-null float64
# p2_Nydus_Worm                                   303 non-null float64
# p2_Observer                                     6754 non-null float64
# p2_Orbital_Command_Upgrade_Command_Center       296 non-null float64
# p2_Overlord                                     12049 non-null float64
# p2_Phoenix                                      1301 non-null float64
# p2_Photon_Cannon                                5897 non-null float64
# p2_Planetary_Fortress_Upgrade_Command_Center    228 non-null float64
# p2_Point_Defense                                486 non-null float64
# p2_Probe                                        11395 non-null float64
# p2_Protoss_Air_Armor_1                          213 non-null float64
# p2_Protoss_Air_Armor_2                          73 non-null float64
# p2_Protoss_Air_Armor_3                          30 non-null float64
# p2_Protoss_Air_Weapons_1                        479 non-null float64
# p2_Protoss_Air_Weapons_2                        150 non-null float64
# p2_Protoss_Air_Weapons_3                        63 non-null float64
# p2_Protoss_Ground_Armor_1                       4763 non-null float64
# p2_Protoss_Ground_Armor_2                       2371 non-null float64
# p2_Protoss_Ground_Armor_3                       1230 non-null float64
# p2_Protoss_Ground_Weapons_1                     6409 non-null float64
# p2_Protoss_Ground_Weapons_2                     4037 non-null float64
# p2_Protoss_Ground_Weapons_3                     2332 non-null float64
# p2_Protoss_Shield_1                             1441 non-null float64
# p2_Protoss_Shield_2                             483 non-null float64
# p2_Protoss_Shield_3                             187 non-null float64
# p2_Pylon                                        11395 non-null float64
# p2_Queen                                        12005 non-null float64
# p2_Raven                                        1107 non-null float64
# p2_Reactor_Barracks                             8873 non-null float64
# p2_Reactor_Factory                              4113 non-null float64
# p2_Reactor_Starport                             3730 non-null float64
# p2_Reaper                                       985 non-null float64
# p2_Refinery                                     10892 non-null float64
# p2_Roach                                        7568 non-null float64
# p2_Roach_Warren                                 8287 non-null float64
# p2_Robotics_Bay                                 4757 non-null float64
# p2_Robotics_Facility                            8371 non-null float64
# p2_SCV                                          11087 non-null float64
# p2_Sensor_Tower                                 1184 non-null float64
# p2_Sentry                                       8109 non-null float64
# p2_Siege                                        6434 non-null float64
# p2_Spawning_Pool                                12052 non-null float64
# p2_Spine_Crawler                                8933 non-null float64
# p2_Spire                                        5823 non-null float64
# p2_Spore_Crawler                                4131 non-null float64
# p2_Stalker                                      10160 non-null float64
# p2_Stargate                                     2306 non-null float64
# p2_Starport                                     9317 non-null float64
# p2_Supply_Depot                                 11085 non-null float64
# p2_Tech_Lab                                     10696 non-null float64
# p2_Templar_Archives                             2494 non-null float64
# p2_Terran_Building                              436 non-null float64
# p2_Terran_Building_Armor                        436 non-null float64
# p2_Terran_Hi-sec_Auto_Tracking                  532 non-null float64
# p2_Terran_Infantry_Armor_1                      5927 non-null float64
# p2_Terran_Infantry_Armor_2                      3561 non-null float64
# p2_Terran_Infantry_Armor_3                      1802 non-null float64
# p2_Terran_Infantry_Weapons_1                    7032 non-null float64
# p2_Terran_Infantry_Weapons_2                    4294 non-null float64
# p2_Terran_Infantry_Weapons_3                    2475 non-null float64
# p2_Terran_Neosteel_Frame                        117 non-null float64
# p2_Terran_Ship_Plating_1                        543 non-null float64
# p2_Terran_Ship_Plating_2                        184 non-null float64
# p2_Terran_Ship_Plating_3                        82 non-null float64
# p2_Terran_Ship_Weapons_1                        1295 non-null float64
# p2_Terran_Ship_Weapons_2                        503 non-null float64
# p2_Terran_Ship_Weapons_3                        188 non-null float64
# p2_Terran_Vehicle_Plating_1                     1176 non-null float64
# p2_Terran_Vehicle_Plating_2                     540 non-null float64
# p2_Terran_Vehicle_Plating_3                     217 non-null float64
# p2_Terran_Vehicle_Weapons_1                     3063 non-null float64
# p2_Terran_Vehicle_Weapons_2                     1564 non-null float64
# p2_Terran_Vehicle_Weapons_3                     641 non-null float64
# p2_Thor                                         1925 non-null float64
# p2_Twilight_Council                             6811 non-null float64
# p2_Ultralisk                                    750 non-null float64
# p2_Ultralisk_Cavern                             985 non-null float64
# p2_Viking                                       4420 non-null float64
# p2_Void                                         1486 non-null float64
# p2_Warp                                         1913 non-null float64
# p2_Zealot                                       10584 non-null float64
# p2_Zerg_Flyer_Attacks_1                         2561 non-null float64
# p2_Zerg_Flyer_Attacks_2                         973 non-null float64
# p2_Zerg_Flyer_Attacks_3                         195 non-null float64
# p2_Zerg_Flyer_Carapace_1                        967 non-null float64
# p2_Zerg_Flyer_Carapace_2                        253 non-null float64
# p2_Zerg_Flyer_Carapace_3                        55 non-null float64
# p2_Zerg_Ground_Carapace_1                       6553 non-null float64
# p2_Zerg_Ground_Carapace_2                       4060 non-null float64
# p2_Zerg_Ground_Carapace_3                       1453 non-null float64
# p2_Zerg_Melee_Attacks_1                         4742 non-null float64
# p2_Zerg_Melee_Attacks_2                         2824 non-null float64
# p2_Zerg_Melee_Attacks_3                         1209 non-null float64
# p2_Zerg_Missile_Attacks_1                       5206 non-null float64
# p2_Zerg_Missile_Attacks_2                       3179 non-null float64
# p2_Zerg_Missile_Attacks_3                       765 non-null float64
# p2_Zergling                                     11819 non-null float64
# p2_an                                           71 non-null float64
# p2_assigned_hotkeys                             34534 non-null int64
# p2_building_types                               34534 non-null int64
# p2_collected_gas                                34534 non-null float64
# p2_collected_minerals                           34534 non-null float64
# p2_max_distance_from_opponent                   34453 non-null float64
# p2_mean_distance_from_opponent                  34453 non-null float64
# p2_min_distance_from_opponent                   34453 non-null float64
# p2_nb_scooting                                  34534 non-null int64
# p2_selected_hotkeys                             34534 non-null int64
# p2_spent_gas                                    34534 non-null int64
# p2_spent_minerals                               34534 non-null int64
# p2_timing_1st_scooting                          34041 non-null float64
# p2_to_Orbital_Command_Command_Center            10860 non-null float64
# p2_to_Planetary_Fortress_Command_Center         3027 non-null float64
# p2_to_Warp_Gate_Gateway                         10680 non-null float64
# p2_unit_types                                   34534 non-null int64
# dtypes: float64(313), int64(15)
# memory usage: 86.4 MB

# %%
# Check columns format : String or numeric
str_list = [] 
for colname, colvalue in df.iteritems():
    if type(colvalue[1]) == str:
         str_list.append(colname)
# Get to the numeric columns by inversion            
num_list = df.columns.difference(str_list)  
len(num_list)
# Only numeric values
# Out:
# 328

# %% [markdown]
# # Proportion of NaN values ?

# %%
def countNaNValues (df):
    """
    Return a list with the number of NaN values in each column 
    """
    
    # List of all features
    df_list = df.columns.values.tolist()
    NaN_list = []
    for feature in df_list:
        NaN_list.append(df[feature].isnull().sum().sum())
    
    return NaN_list



def countNaNRate(df, colName) :
    """
    Return a list of 10 items
    with how many columns have more than 0 to 90 %
    of NaN values
    
    """
    
    NaN_list = countNaNValues(df)
    NaN_rate =[]
    df_list = df.columns.values.tolist()
    
    for j in range(10):
        count = 0
        for i in range(len(df_list)):
            if (NaN_list[i]>0.1*j*len(df[colName])):
                count +=1  
        NaN_rate.append(count)
    return NaN_rate

# %%
NaN_rate = countNaNRate(df, "_p1_win_game")
NaN_rate
# 216/328 columns with more than 80 % NaN values
# 32/328 columns with less than 10 % NaN values
# Out:
# [304, 296, 296, 296, 296, 296, 296, 255, 216, 157]

# %%
# Light dataset :  only these 32 columns    
NaN_list = countNaNValues(df)
features = df.columns.values.tolist()
toErase = []
for i in range(len(features)):
    # 90 % of non NaN values 
    if (NaN_list[i]>0.1*len(df._p1_win_game)):
        toErase.append(features[i])
        
df_light = df.drop(toErase, axis=1)
len(df_light.columns)
# Out:
# 32

# %%
# Change NaN values to zero (more meaning than median)
df = df.fillna(value=0, axis=1) #(328 columns)
df_light = df_light.fillna(value=0, axis=1) #(32 columns)

# %%
# As columns are the same for most of the columns, decrease columns number by feature = p1_feature - p2_feature  
# only for df_light
colnames = df_light.columns.values

# sub_lists for each player 
p1_colnames = [name[3:] for name in colnames if "p1" in name]
p2_colnames = [name[3:] for name in colnames if "p2" in name]
colnames = [name for name in p1_colnames if name in p2_colnames ]
print len(colnames)
# 15 dimensions
# Out:
# 15

# %%
colnames
# Out:
# ['APM',
#  'APM_wo_select',
#  'assigned_hotkeys',
#  'building_types',
#  'collected_gas',
#  'collected_minerals',
#  'max_distance_from_opponent',
#  'mean_distance_from_opponent',
#  'min_distance_from_opponent',
#  'nb_scooting',
#  'selected_hotkeys',
#  'spent_gas',
#  'spent_minerals',
#  'timing_1st_scooting',
#  'unit_types']

# %%
df_light.columns.values
# Out:
# array(['_p1_win_game', 'game_length', 'p1_APM', 'p1_APM_wo_select',
#        'p1_assigned_hotkeys', 'p1_building_types', 'p1_collected_gas',
#        'p1_collected_minerals', 'p1_max_distance_from_opponent',
#        'p1_mean_distance_from_opponent', 'p1_min_distance_from_opponent',
#        'p1_nb_scooting', 'p1_selected_hotkeys', 'p1_spent_gas',
#        'p1_spent_minerals', 'p1_timing_1st_scooting', 'p1_unit_types',
#        'p2_APM', 'p2_APM_wo_select', 'p2_assigned_hotkeys',
#        'p2_building_types', 'p2_collected_gas', 'p2_collected_minerals',
#        'p2_max_distance_from_opponent', 'p2_mean_distance_from_opponent',
#        'p2_min_distance_from_opponent', 'p2_nb_scooting',
#        'p2_selected_hotkeys', 'p2_spent_gas', 'p2_spent_minerals',
#        'p2_timing_1st_scooting', 'p2_unit_types'], dtype=object)

# %%
# new DataFrame : p1-p2 for each column
df_light2 = pd.DataFrame()

for name in colnames:
    # filtered_df est une DataFrame
    # Pour chaque série de doublons (ex : p1_APM et p2_APM, filtered_df contient deux colonnes)
    filtered_df = df_light.filter(regex=name+'$')
    # For each line except the first, difference between p1 and p2 data
    df_light2[name[:]] = filtered_df.iloc[:,0]-filtered_df.iloc[:,1]

df_light2.head()
# Out:
#           APM  APM_wo_select  assigned_hotkeys  building_types  collected_gas  \
# 0  -52.514968     -24.194918               -21               1     -98.407317
# 1   47.431682      13.239911                 9              -2     591.851395
# 2 -155.331871     -13.846281                -1               5    -484.647238
# 3  136.910425      38.996989                 1               1    1706.586960
# 4  -31.537314      28.962773                 0               2   -1274.017014
#
#    collected_minerals  max_distance_from_opponent  \
# 0         3178.767457                    8.921409
# 1         6956.071907                   -3.092666
# 2         2750.713222                    1.934465
# 3        -2021.543155                   -2.190440
# 4        -3840.025920                    0.077156
#
#    mean_distance_from_opponent  min_distance_from_opponent  nb_scooting  \
# 0                    13.573083                    2.755987          -25
# 1                    -1.339119                    3.575096           -9
# 2                    11.663239                    2.601839         -117
# 3                   -35.552794                 -102.610951           24
# 4                   -43.765192                    1.478506           62
#
#    selected_hotkeys  spent_gas  spent_minerals  timing_1st_scooting  \
# 0              -396       1025            2725           -41.638376
# 1              -173      -2300           -7575           -48.495400
# 2                 2       -125           -2000          -313.573512
# 3               -76       2125           -2675           117.110752
# 4                14      -1225           -1000          -471.465512
#
#    unit_types
# 0           0
# 1          -1
# 2           1
# 3           4
# 4           2

# %% [markdown]
# ## Diagramme de corrélation des 15 caractéristiques

# %%
# Set up the matplotlib figure
g, ax2 = plt.subplots(figsize=(8, 8))
plt.title('Pearson Correlation of StarCraft Features. Dataset X2')
# Draw the heatmap using seaborn
sns.heatmap(df_light2.astype(float).corr(),linewidths=0.25,vmax=1.0, square=True, linecolor='black')

# %% [markdown]
# Forte corrélation entre :
# * APM et APM_wo_selected
# * spent_gas and spent_mineral

# %% [markdown]
# # Standardization

# %%
X1 = df.iloc[:,1:]
X2 = df_light2

# Data Normalization
from sklearn.preprocessing import StandardScaler
X1_std = StandardScaler().fit_transform(X1)
X2_std = StandardScaler().fit_transform(X2)

# %% [markdown]
# # PCA
# The typical goal of a PCA is to reduce the dimensionality of the original feature space by projecting it onto a smaller subspace, where the eigenvectors will form the axes.
# Analyse PCA : principal component analysis, et en amont, choix du nombre de composantes à conserver via Explained Variance

# %%
# Calculating Eigenvectors and eigenvalues of Cov matirx
mean_vec = np.mean(X2_std, axis=0)
cov_mat = np.cov(X2_std.T)
eig_vals, eig_vecs = np.linalg.eig(cov_mat)
# Create a list of (eigenvalue, eigenvector) tuples
eig_pairs = [ (np.abs(eig_vals[i]),eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort from high to low
eig_pairs.sort(key = lambda x: x[0], reverse= True)

# Calculation of Explained Variance from the eigenvalues
tot = sum(eig_vals)
var_exp = [(i/tot)*100 for i in sorted(eig_vals, reverse=True)] # Individual explained variance
cum_var_exp = np.cumsum(var_exp) # Cumulative explained variance

# %%
# PLOT OUT THE EXPLAINED VARIANCES SUPERIMPOSED 
plt.figure(figsize=(8, 5))
plt.bar(range(15), var_exp, alpha=0.3333, align='center', label='individual explained variance', color = 'g')
plt.step(range(15), cum_var_exp, where='mid',label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.axhline(y=90,color='y')
plt.axhline(y=95,color='r')
plt.axvline(x=10,color='y')
plt.axvline(x=11,color='r')
plt.legend(loc='best')
plt.show()
# 90 % of information described by 10/15 features
# 95 % of information described by 11/15 features

# %% [markdown]
# Avec la projection, on a perdu l'info explicite de l'importance d'une colonne
# On peut choisir de ne conserver que les 11 plus importants nouveaux axes par exemple

# %%
from sklearn.decomposition import PCA as sklearnPCA
pca = sklearnPCA(n_components=11)
x_11d = pca.fit_transform(X2_std)

# %%
x_11d[0]
# Out:
# array([ 1.38351358, -0.36979979, -0.0883399 ,  0.78674256, -0.65895497,
#         0.57093231, -0.41285644,  0.16873403, -0.14022969, -0.07290467,
#         0.15658155])

# %% [markdown]
# ## On a deux jeux de données, 1 à 328 caractéristiques, l'autre à 11

# %%
y = df._p1_win_game.as_matrix()

# %% [markdown]
# Split les jeux de données (jeu de training (80%) et testing (20%))

# %%
# old cross_validation module becomes new model_selection module
from sklearn.model_selection import train_test_split
X1_train, X1_test, y_train, y_test = train_test_split(X1_std, y, test_size=0.2)
X2_train, X2_test, y_train, y_test = train_test_split(x_11d, y, test_size=0.2)

# %% [markdown]
# ## Les modeles :
#
# 1. regression logistique, comme ligne de base
# 2. SVM : alternative à la LR si dependance non lineaire des features. Difficile a entrainer. Efficace sur hautes dimensions
# 3. tree ensembles :  Random Forests (Algorithm) and Gradient Boosted Trees. Fonctionnent bien sur categories binaires
# et ne nécessite pas de séparation lineaire

# %%
# Import de toute une serie d'estimateurs ?
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.linear_model import LogisticRegression as LR
from sklearn.ensemble import GradientBoostingClassifier as GBC
from sklearn.linear_model import Perceptron as PPN
from sklearn.metrics import average_precision_score
#import xgboost
# une methode pour evaluer la precision des modeles
def accuracy(y_true,y_pred):
    # NumPy interpretes True and False as 1. and 0.
    return np.mean(y_true == y_pred)

# %%
#KFold : pour diviser les données : évite notamment l'overfitting
#from sklearn.cross_validation  import KFold
from sklearn.model_selection import KFold
#** arguments sous la forme de dico
#X : les donnees
#y : les resultats
#clf_class : un type de classifier : par exemple l'estimateur SVC

def run_cv(X,y,clf_class,**kwargs):
    # Construct a kfolds object
    #KFold : len(y)?
    # nombre de portions:3, et regroupement des données identiques avant decoupage
    # kf = KFold(len(y),n_folds=3,shuffle=True)
    kf = KFold(n_splits=3)
    # copie la DataFrame des resultats
    y_pred = y.copy()
    
    # Iterate through folds
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train = y[train_index]
        # un classifier est un exemple d'estimator, un objet python qui implemente les 
        # methodes .fit(X,y) et predict(T) 
        # Initialize a classifier with keyword arguments
        clf = clf_class(**kwargs)
        # le classifier apprend du modele grace au jeu d'entrainement
        clf.fit(X_train,y_train)
        # puis predit de nouvelles valeurs via le jeu de test
        y_pred[test_index] = clf.predict(X_test)
    return y_pred
# la fonction renvoie les resultats prédits pour le jeu de test (prochaine etape : evaluer l'erreur de la prediction)

# %%
# Test des differents modeles
# Plus grande precision : Logistic Regression LR
print "Logistic Regression:"
print "%.3f" % accuracy(y, run_cv(X2_std,y,LR))
print "Gradient Boosting Classifier"
print "%.3f" % accuracy(y, run_cv(X2_std,y,GBC))
#print "XGB Classifier"
#print "%.3f" % accuracy(y, run_cv(X2_std,y,XGB))
print "Support vector machines:"
print "%.3f" % accuracy(y, run_cv(X2_std,y,SVC))
print "Random forest:"
print "%.3f" % accuracy(y, run_cv(X2_std,y,RF))
print "K-nearest-neighbors:"
print "%.3f" % accuracy(y, run_cv(X2_std,y,KNN))
# Out:
# Logistic Regression:
# 0.676
# Gradient Boosting Classifier
# 0.687
# Support vector machines:
# 0.687
# Random forest:
# 0.647
# K-nearest-neighbors:
# 0.627

# %% [markdown]
# En moyenne, ** perte de  4 %  de précision ** pour une grande diminution de la dimensionnalité (328 -> 15).
# Peut être utile dans les phases d'optimisation des algorithmes, le SVM notamment, présentant un mauvais scaling

# %% [markdown]
# # Optimisation des algorithmes prédictifs
# ## Logistic Regression

# %%
# Logistic Regression

y_LR_pred=[]
# Set regularization parameter
for i, C in enumerate((100, 1, 0.01)):
    # turn down tolerance for short training time
    clf_l0_LR = LR(C=C, penalty='l1', tol=0.001)
    clf_l1_LR = LR(C=C, penalty='l1', tol=0.01)
    clf_l2_LR = LR(C=C, penalty='l2', tol=0.01)
    clf_l0_LR.fit(X2_train, y_train)
    clf_l1_LR.fit(X2_train, y_train)
    clf_l2_LR.fit(X2_train, y_train)
    y_LR_pred.append(clf_l0_LR.predict(X2_test))
    y_LR_pred.append(clf_l1_LR.predict(X2_test))
    y_LR_pred.append(clf_l2_LR.predict(X2_test))
acc_LR=[]
for y_pred in y_LR_pred:
    acc_LR.append(accuracy(y_test, y_pred))
acc_LR.index(max(acc_LR))
# meilleur jeu = LR(C=0.01, penalty='l1', tol=0.001)

# %% [markdown]
# ##  RandomForestClassifier

# %%
acc_RF=[]
for n in range (10, 200, 10 ):
    clf_RF = RF(n_estimators=n)
    clf_RF.fit(X2_train, y_train)
    y_pred = clf_RF.predict(X2_test)
    acc_RF.append(accuracy(y_test, y_pred))
acc_RF.index(max(acc_RF))
# meilleur jeu = RF(n_estimators=140)

# %%
# Support Vector Machine

y_SVM_pred=[]
# Set regularization parameter
for i, C in enumerate((100, 1, 0.01)):
    for kernel in ['linear', 'rbf', 'poly']:
        # turn down tolerance for short training time
        clf_SVM = SVC(C=C, kernel=kernel, tol=0.001)
        clf_SVM.fit(X2_train, y_train)
        y_SVM_pred.append(clf_SVM.predict(X2_test))
acc_SVM=[]
for y_pred in y_SVM_pred:
    acc_SVM.append(accuracy(y_test, y_pred))
acc_SVM.index(max(acc_SVM))
# meilleur jeu = LR(C=0.01, penalty='l1', tol=0.001)

# %% [markdown]
# # Test final

# %%
# Test des differents modeles
# Plus grande precision : Logistic Regression LR
print "Logistic Regression:"
print "%.3f" % accuracy(y, run_cv(X1_std,y,LR, C=0.01, penalty='l1', tol=0.001))
print "Gradient Boosting Classifier"
print "%.3f" % accuracy(y, run_cv(X1_std,y,GBC))
#print "XGB Classifier"
#print "%.3f" % accuracy(y, run_cv(X2_std,y,XGB))
print "Support vector machines:"
print "%.3f" % accuracy(y, run_cv(X1_std,y,SVC))
print "Random forest:"
print "%.3f" % accuracy(y, run_cv(X1_std,y,RF,n_estimators=140))
print "K-nearest-neighbors:"
print "%.3f" % accuracy(y, run_cv(X1_std,y,KNN))

# %% [markdown]
# Apprentissage non supervisé : K-Means

# %%
X2.head()
# Out:
#           APM  APM_wo_select  assigned_hotkeys  building_types  collected_gas  \
# 0  -52.514968     -24.194918               -21               1     -98.407317
# 1   47.431682      13.239911                 9              -2     591.851395
# 2 -155.331871     -13.846281                -1               5    -484.647238
# 3  136.910425      38.996989                 1               1    1706.586960
# 4  -31.537314      28.962773                 0               2   -1274.017014
#
#    collected_minerals  max_distance_from_opponent  \
# 0         3178.767457                    8.921409
# 1         6956.071907                   -3.092666
# 2         2750.713222                    1.934465
# 3        -2021.543155                   -2.190440
# 4        -3840.025920                    0.077156
#
#    mean_distance_from_opponent  min_distance_from_opponent  nb_scooting  \
# 0                    13.573083                    2.755987          -25
# 1                    -1.339119                    3.575096           -9
# 2                    11.663239                    2.601839         -117
# 3                   -35.552794                 -102.610951           24
# 4                   -43.765192                    1.478506           62
#
#    selected_hotkeys  spent_gas  spent_minerals  timing_1st_scooting  \
# 0              -396       1025            2725           -41.638376
# 1              -173      -2300           -7575           -48.495400
# 2                 2       -125           -2000          -313.573512
# 3               -76       2125           -2675           117.110752
# 4                14      -1225           -1000          -471.465512
#
#    unit_types
# 0           0
# 1          -1
# 2           1
# 3           4
# 4           2

# %%
x = X2.columns.values.tolist()

y = df._p1_win_game.as_matrix()
x
# Out:
# ['APM',
#  'APM_wo_select',
#  'assigned_hotkeys',
#  'building_types',
#  'collected_gas',
#  'collected_minerals',
#  'max_distance_from_opponent',
#  'mean_distance_from_opponent',
#  'min_distance_from_opponent',
#  'nb_scooting',
#  'selected_hotkeys',
#  'spent_gas',
#  'spent_minerals',
#  'timing_1st_scooting',
#  'unit_types']

# %%
# Set the size of the plot
plt.figure(figsize=(14,7))
 
# Create a colormap
colormap = np.array(['red', 'green'])
 
# Plot gas
plt.subplot(1, 2, 1)
plt.scatter(X2.spent_gas, X2.collected_gas, c=colormap[y], s=40)
plt.title('gas')

# Plot minerals
plt.subplot(1, 2, 2)
plt.scatter(X2.spent_minerals, X2.collected_minerals, c=colormap[y], s=40)
plt.title('minerals')

# %%
# Set the size of the plot
plt.figure(figsize=(14,7))
 
# Create a colormap
colormap = np.array(['red', 'green', 'blue'])
 
# Plot gas
plt.subplot(1, 2, 1)
plt.scatter(X2.spent_gas, X2.collected_gas, c=colormap[y], s=40)
plt.title('gas')

# Plot minerals
plt.subplot(1, 2, 2)
plt.scatter(X2.spent_minerals, X2.collected_minerals, c=colormap[y], s=40)
plt.title('minerals')

# %%
#RF : RandomForestClassifier
forest = RF(n_estimators=140)
forest_fit = forest.fit(X2_train, y_train)
forest_prediction = forest_fit.predict(X2_test)

# renvoie un array avec les importances relatives des 10 premieres caracteristiques
importances = forest_fit.feature_importances_[:10]

# numpy.std : Returns the standard deviation, a measure of the spread of a distribution
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
# Renvoie un tableau des indices dans l'ordre où ils seraient après un tri
indices = np.argsort(importances)[::-1]

#Print the feature ranking
print("Feature ranking:")
features = [x for y, x in sorted(zip(importances, X2.columns.values), reverse=True)]

for f in range(10):
    print("%d. %s (%f)" % (f+1, features[f], importances[indices[f]]))
    
#plot the feature importances of the forest
plt.figure()
plt.title("Feature importance")
plt.bar(range(10), importances[indices], yerr=std[indices], color="b", align="center")
plt.xticks(range(10), indices)
plt.xlim([-1,10])
plt.show()
# Out:
# Feature ranking:
# 1. APM_wo_select (0.130407)
# 2. APM (0.099487)
# 3. assigned_hotkeys (0.094837)
# 4. max_distance_from_opponent (0.094457)
# 5. mean_distance_from_opponent (0.092576)
# 6. collected_gas (0.088060)
# 7. nb_scooting (0.081944)
# 8. min_distance_from_opponent (0.081066)
# 9. collected_minerals (0.079810)
# 10. building_types (0.079611)

# %%
y = df._p1_win_game.as_matrix()
# Set the size of the plot
plt.figure(figsize=(14,7))
 
# Create a colormap
colormap = np.array(['red', 'blue', 'green', 'orange','brown','black', 'pink'])
 
# Plot gas
plt.subplot(1, 2, 1)
plt.scatter(X2.APM_wo_select, X2.assigned_hotkeys, X2.max_distance_from_opponent, X2.building_types, X2.collected_minerals, c=colormap[y], s=40)
plt.title('keys')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-26e2b197a5bf> in <module>()
#       8 # Plot gas
#       9 plt.subplot(1, 2, 1)
# ---> 10 plt.scatter(X2.APM_wo_select, X2.assigned_hotkeys, X2.max_distance_from_opponent, X2.building_types, X2.collected_minerals, c=colormap[y], s=40)
#      11 plt.title('keys')
#      12
#
# TypeError: scatter() got multiple values for keyword argument 'c'

# %%
from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier

# Build a classification task using 3 informative features
X, y = make_classification(n_samples=1000,
                           n_features=10,
                           n_informative=3,
                           n_redundant=0,
                           n_repeated=0,
                           n_classes=2,
                           random_state=0,
                           shuffle=False)

# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=250,
                              random_state=0)

forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 1 (0.295902)
# 2. feature 2 (0.208351)
# 3. feature 0 (0.177632)
# 4. feature 3 (0.047121)
# 5. feature 6 (0.046303)
# 6. feature 8 (0.046013)
# 7. feature 7 (0.045575)
# 8. feature 4 (0.044614)
# 9. feature 9 (0.044577)
# 10. feature 5 (0.043912)

# %%
from sklearn.cluster import KMeans 

# Set a 2 KMeans clustering
kmeans = KMeans(n_clusters=2, init='k-means++')
# Compute cluster centers and predict cluster indices
X_clustered = kmeans.fit_predict(X2_std)
# Define our own color map
LABEL_COLOR_MAP = {0 : 'r',1 : 'g',2 : 'b', 3:'black', 4:'brown'}
label_color = [LABEL_COLOR_MAP[l] for l in X_clustered]
for i in range(10):
    for j in [i+1,10]:
        # Plot the scatter digram
        plt.scatter(X2_std[:,i],X2_std[:,j], c= label_color, label='Class 1',alpha=0.5) 
        plt.xlabel(X2.columns.values[i])
        plt.ylabel(X2.columns.values[j])
        plt.show()
